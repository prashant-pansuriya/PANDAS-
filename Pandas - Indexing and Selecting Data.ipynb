# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(8, 4),
index = ['a','b','c','d','e','f','g','h'], columns = ['A', 'B', 'C', 'D'])

#select all rows for a specific column
df.loc[:,'A']
# Out:
# a    0.040727
# b    0.616569
# c   -0.113081
# d   -0.837642
# e   -0.613956
# f   -2.683239
# g   -0.966478
# h    1.270435
# Name: A, dtype: float64

# %%
df = pd.DataFrame(np.random.randn(8, 4),
index = ['a','b','c','d','e','f','g','h'], columns = ['A', 'B', 'C', 'D'])

# Select all rows for multiple columns, say list[]
df.loc[:,['A','C']]
# Out:
#           A         C
# a -0.175474  1.512589
# b -0.826611  0.444028
# c -0.864157 -0.701368
# d  0.063912 -0.406923
# e -0.536048  0.629041
# f -1.614129  0.651092
# g  0.010569  0.863958
# h  2.599501 -0.424344

# %%
df = pd.DataFrame(np.random.randn(8, 4),
index = ['a','b','c','d','e','f','g','h'], columns = ['A', 'B', 'C', 'D'])

# Select few rows for multiple columns, say list[]
df.loc[['a','b','f','h'],['A','C']]
# Out:
#           A         C
# a  1.303537  0.955457
# b  1.189543 -0.425145
# f -0.834219 -0.058825
# h  0.186783  0.259530

# %%
df = pd.DataFrame(np.random.randn(8, 4),
index = ['a','b','c','d','e','f','g','h'], columns = ['A', 'B', 'C', 'D'])

# Select range of rows for all columns
df.loc['a':'h']
# Out:
#           A         B         C         D
# a -0.924378  0.098054  0.553946  0.700279
# b -1.276234 -1.330825  0.574262 -0.093751
# c -0.611702  1.175442  1.952375  0.475771
# d  0.055646 -1.249914  0.372661  0.266659
# e -2.918028  1.983969 -0.438286  0.838967
# f -0.508875 -1.485993 -0.768629  0.135023
# g  0.219158 -0.454780  1.875547 -1.415513
# h  0.055737 -0.286753  1.159286 -1.288736

# %%
df = pd.DataFrame(np.random.randn(8, 4),
index = ['a','b','c','d','e','f','g','h'], columns = ['A', 'B', 'C', 'D'])

# for getting values with a boolean array
df.loc['a']>0
# Out:
# A    False
# B     True
# C    False
# D     True
# Name: a, dtype: bool

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns = ['A', 'B', 'C', 'D'])

# select all rows for a specific column
df.iloc[:4]
# Out:
#           A         B         C         D
# 0 -1.735461 -1.260583 -0.949075 -2.264801
# 1 -0.342227  1.190820 -1.757446  1.227189
# 2  0.062808  1.695106  1.713980  0.663822
# 3 -0.979081 -0.407842  1.412683  1.238950

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns = ['A', 'B', 'C', 'D'])

# Integer slicing
print (df.iloc[:4])
print (df.iloc[1:5, 2:4])
# Out:
#           A         B         C         D
# 0 -0.145971  1.820951  1.475578  0.689007
# 1 -0.645010  0.179571 -0.655829  1.157407
# 2  1.549263 -1.456336  0.833841  1.072418
# 3 -1.217316 -1.620834 -1.042267 -0.207998
#           C         D
# 1 -0.655829  1.157407
# 2  0.833841  1.072418
# 3 -1.042267 -0.207998
# 4  0.527871 -1.185838

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns = ['A', 'B', 'C', 'D'])

# Slicing through list of values
print (df.iloc[[1, 3, 5], [1, 3]])
print (df.iloc[1:3, :])
print (df.iloc[:,1:3])
# Out:
#           B         D
# 1 -0.170595 -1.343233
# 3  0.930325 -0.470973
# 5 -0.501186 -0.472326
#           A         B         C         D
# 1 -0.014845 -0.170595  0.563023 -1.343233
# 2 -2.269197  0.501277 -0.095682 -1.063744
#           B         C
# 0 -0.554771 -0.997845
# 1 -0.170595  0.563023
# 2  0.501277 -0.095682
# 3  0.930325  0.781734
# 4  0.146182 -0.180489
# 5 -0.501186  1.722452
# 6  0.564209 -0.340305
# 7  0.248600  0.527787

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns = ['A', 'B', 'C', 'D'])

# Integer slicing
df.ix[:4]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
#           A         B         C         D
# 0 -0.677940 -0.257005 -0.396224  1.030344
# 1  0.763550 -0.956748 -2.864336 -0.230352
# 2 -0.980747 -1.793606 -0.566895  1.306832
# 3  0.493366  0.342271  0.805511  1.572684
# 4 -0.035991  1.229827  0.645902 -0.565178

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns = ['A', 'B', 'C', 'D'])
# Index slicing
df.ix[:,'A']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0    0.354937
# 1    0.638258
# 2    0.506037
# 3    1.410833
# 4    1.311979
# 5    0.342919
# 6    1.066241
# 7    0.509885
# Name: A, dtype: float64

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns = ['A', 'B', 'C', 'D'])
df['A']
# Out:
# 0   -1.324001
# 1    1.055730
# 2    0.512036
# 3    0.679326
# 4    1.565195
# 5    0.298265
# 6   -0.681379
# 7   -1.023748
# Name: A, dtype: float64

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns = ['A', 'B', 'C', 'D'])

df[['A','B']]
# Out:
#           A         B
# 0 -0.939253  1.309699
# 1  0.629509  0.500727
# 2  0.712352 -1.184754
# 3  0.305032 -0.690837
# 4 -0.947957  0.670453
# 5  0.746828  0.783322
# 6 -0.096772 -2.133227
# 7  1.330634 -0.890634

# %%
df[0:2]
# Out:
#           A         B         C         D
# 0 -0.939253  1.309699 -0.968076 -0.968408
# 1  0.629509  0.500727 -1.550323 -0.667659

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns = ['A', 'B', 'C', 'D'])

df.A
# Out:
# 0   -1.246200
# 1    0.640793
# 2   -0.025879
# 3   -1.456929
# 4   -1.920939
# 5   -0.008912
# 6   -1.177628
# 7    0.541222
# Name: A, dtype: float64
